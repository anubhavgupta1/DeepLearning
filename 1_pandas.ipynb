# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhavgupta1/DeepLearning/blob/master/1_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once in a notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a text file.
uploaded = drive.CreateFile({'title': 'Sample file.txt'})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1MDDkGkO7qDQXjsba_J1W70lgHFvDcvHN

# %%
# Create & upload a text file.
uploaded = drive.CreateFile({'title': 'File2.txt'})
uploaded.SetContentString('Hello Anubhav')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 143ljAbI0fFRpCzc3g_ElI0Ojs0ZUvnYL

# %%
# List .txt files in the root.
#
# Search query reference:
# https://developers.google.com/drive/v2/web/search-parameters
listed = drive.ListFile({'q': "title contains '.csv' and 'root' in parents"}).GetList()
for file in listed:
  print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title mobile_cleaned2.csv, id 12Ya_2UtrBrWpY4o-6YELClLSfoqXpuQG

# %%
# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1V6qHWz4i6s8qt7vGWAG7r9nHM3lM7lNG' #https://drive.google.com/open?id=1V6qHWz4i6s8qt7vGWAG7r9nHM3lM7lNG
downloaded = drive.CreateFile({'id': file_id})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "sim_type,aperture,gpu_rank,weight,stand_by_time,processor_frequency,thickness,flash_type,front_camera_resolution,auto_focus,screen_size,frames_per_second,FM,no_of_reviews_in_gsmarena_in_week,os,phone_height,screen_protection,sim_size,price,talk_time,video_resolution,display_resolution,removable_battery,display_type,primary_camera_resolution,battery_type,ram_memory,internal_memory,brand_rank,no_of_cores,micro_sd_slot,screen_pixel_density,water_proof_rate,phone_width,expandable_memory,version,usb_type,battery_capacity,processor_rank,is_liked
# 0,12,55,155.0,250,1.3,10.5,5,2.0,0,4.5,15,3,0,0,132.9,26,3,3870,9,480,12,3,11,5.0,1,1,7,29,6,4,2,3,67.8,64.0,5,3,2000,125,1
# 0,1,55,132.0,300,1.3,10.6,5,0.3,1,4.0,30,2,6,0,124.5,26,5,4059,9,720,15,3,11,5.0,1,1,7,11,6,4,4,6,64.0,32.0,5,3,2000,165,1
# 0,9,55,142.0,329,1.5,8.5,5,2.0,3,5.0,30,2,20,0,145.5,4,3,4777,10,1080,4,3,1,5.04,2,1,7,27,6,4,9,6,72.0,32.0,6,3,2500,164,0
# ...

# %%
downloaded.GetContentFile('mobile_cleaned_local.csv')

# %%
# !ls
# Out:
# adc.json  mobile_cleaned_local.csv  sample_data

# %%
import pandas as pd

data = pd.read_csv('mobile_cleaned_local.csv') #data frame
data.head()
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
data.tail()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# 108         2         8         3  ...              3000               2         0
#
# [5 rows x 40 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(data)
# Out:
# ['FM',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
data.shape
# Out:
# (109, 40)

# %%
data.loc[5]
# Out:
# sim_type                                0.0
# aperture                               14.0
# gpu_rank                               55.0
# weight                                179.0
# stand_by_time                         280.0
# processor_frequency                     1.3
# thickness                               7.9
# flash_type                              5.0
# front_camera_resolution                 5.0
# auto_focus                              3.0
# screen_size                             5.5
# frames_per_second                      30.0
# FM                                      3.0
# no_of_reviews_in_gsmarena_in_week       6.0
# os                                      0.0
# phone_height                          150.0
# screen_protection                       5.0
# sim_size                                3.0
# price                                5999.0
# talk_time                              22.0
# video_resolution                      720.0
# ...

# %%
data_short = data[0:10]
data_short.shape
# Out:
# (10, 40)

# %%
data_short.head()
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
data_thin = data[['stand_by_time','expandable_memory','price','battery_capacity','is_liked']]
data_thin.head()
# Out:
#    stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0            250               64.0   3870              2000         1
# 1            300               32.0   4059              2000         1
# 2            329               32.0   4777              2500         0
# 3            385               32.0   5799              3000         1
# 4            385               32.0   5990              3000         0

# %%
data_thin.shape
# Out:
# (109, 5)

# %%
data_thin['is_liked']==1
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 104     True
# 105     True
# 106     True
# 107     True
# 108    False
# Name: is_liked, Length: 109, dtype: bool

# %%
print(data_thin[data_thin['is_liked']==1])
# Out:
#      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 0              250               64.0   3870              2000         1
# 1              300               32.0   4059              2000         1
# 3              385               32.0   5799              3000         1
# 6              230              128.0   5999              1700         1
# 7              182               32.0   6599              2000         1
# ..             ...                ...    ...               ...       ...
# 103            600              256.0  52699              3430         1
# 104            540              256.0  54900              3410         1
# 105            400              200.0  56900              3600         1
# 106            384                0.0  59000              2750         1
# 107            250                0.0  64500              1810         1
#
# [92 rows x 5 columns]

# %%
data_is_liked = data_thin[data_thin['is_liked']==1]
data_is_liked.shape
# Out:
# (92, 5)

# %%
data_thin['price'].mean()
# Out:
# 19373.211009174312

# %%
data_thin['price'].min()
# Out:
# 3870

# %%
data_thin['price'].max()
# Out:
# 64500

# %%
data_thin['price'].count()
# Out:
# 109

# %%
data_thin['price'].describe()
# Out:
# count      109.000000
# mean     19373.211009
# std      14039.197220
# min       3870.000000
# 25%       8999.000000
# 50%      14614.000000
# 75%      24999.000000
# max      64500.000000
# Name: price, dtype: float64

# %%
data_thin.describe()
# Out:
#        stand_by_time  expandable_memory  ...  battery_capacity    is_liked
# count      109.00000         109.000000  ...        109.000000  109.000000
# mean       404.66055         104.513761  ...       2841.779817    0.844037
# std        176.44206         275.799767  ...        655.003963    0.364496
# min        160.00000           0.000000  ...       1560.000000    0.000000
# 25%        264.00000           0.000000  ...       2470.000000    1.000000
# 50%        360.00000          32.000000  ...       2900.000000    1.000000
# 75%        500.00000         128.000000  ...       3100.000000    1.000000
# max       1093.00000        2048.000000  ...       5000.000000    1.000000
#
# [8 rows x 5 columns]

# %%
data_thin[data_thin['is_liked']==1]['price'].mean()
# Out:
# 19393.239130434784

# %%
data_thin[data_thin['is_liked']==0]['price'].mean()
# Out:
# 19264.823529411766

# %%
data_thin_is_liked_grouped = data_thin.groupby(['is_liked'])

# %%
for key,data_key in data_thin_is_liked_grouped:
  print(str(key) + " : " + str(data_key))
# Out:
# 0 :      stand_by_time  expandable_memory  price  battery_capacity  is_liked
# 2              329               32.0   4777              2500         0
# 4              385               32.0   5990              3000         0
# 5              280               32.0   5999              2900         0
# 11             300              128.0   6990              2600         0
# 22             354              128.0   7999              2400         0
# 38             490               32.0   9999              2100         0
# 53             345               64.0  14300              2950         0
# 60             840                0.0  15689              4100         0
# 74             390              128.0  21999              2800         0
# 77             620              128.0  22999              3100         0
# 78             618                0.0  24499              3600         0
# 80             598                0.0  24999              3000         0
# ...

# %%
data_thin_is_liked_grouped.mean()
# Out:
#           stand_by_time  expandable_memory         price  battery_capacity
# is_liked
# 0            457.235294          68.235294  19264.823529       2874.941176
# 1            394.945652         111.217391  19393.239130       2835.652174

# %%
data_thin_is_liked_grouped.describe()
# Out:
#          stand_by_time                          ... battery_capacity
#                  count        mean         std  ...              50%     75%     max
# is_liked                                        ...
# 0                 17.0  457.235294  157.094927  ...           2900.0  3000.0  4100.0
# 1                 92.0  394.945652  178.876246  ...           2900.0  3100.0  5000.0
#
# [2 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
ax = sns.pairplot(data_thin, diag_kind='hist')

# %%
ax = sns.pairplot(data_thin, diag_kind='hist',hue='is_liked')
